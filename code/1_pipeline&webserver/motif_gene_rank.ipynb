# %%
import matplotlib.pyplot as plt
import numpy as np ,pandas as pd
from collections import OrderedDict,Counter
import os
import statsmodels.stats.multitest as multi
import scipy.stats as stats
from collections import Counter
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
import math

# %%
dir="E:\\project\\singcells\\MEME\\ATtRACT\\p\\p_min\\"

# %%
df_p_min=pd.read_csv(dir+"motif_gene_p_find.txt",header=0,sep="\t",index_col=0)

# %%
df_p_min.head(3)
# Out:
#           HNRNPK_GGGGGGG_1042  NOVA1_AGCACC_s27  HNRNPL_ACACGAC_M089_0.6  \
# STK11                0.000030          0.000237                 0.000144
# ADAMTSL1             0.000030          0.000237                 0.000144
# GPR89B               0.000237          0.000237                 0.000144
#
#           SRSF1_GACCCGG_1238  NOVA1_UCACC_459  PCBP2_ACCUUAAA_785  \
# STK11               0.000036         0.000864            0.000129
# ADAMTSL1            0.000036         0.000864            0.000022
# GPR89B              0.000036         0.000864            0.000129
#
#           HNRNPC_UUUUUUG_M025_0.6  G3BP1_ACCCAUACGCCC_33  \
# STK11                    0.000118               0.000003
# ADAMTSL1                 0.000118               0.000002
# GPR89B                   0.000118               0.000001
#
#           SRSF10_AGAGAAA_M087_0.6  HNRNPH1_CUGGGGGCUG_879         ...          \
# STK11                    0.000079                0.000002         ...
# ...

# %%
start_order=df_p_min.index.tolist()

df_rank=pd.DataFrame()

for col0 in df_p_min.columns:
    df_test_sort_b=df_p_min.sort_values(by=col0,ascending=True)
    ind_index=OrderedDict({})

    i=1
    for ww in df_test_sort_b.index:
        ind_index[ww]=i
        i=i+1
    rank_0=[]
    for ww in start_order:
        rank_0.append(ind_index[ww])
    df_rank[col0]=rank_0
df_rank.index=start_order

df_rank.T.to_csv(dir+"motif_gene_rank.txt",sep="\t",header=True,index=True)
# Out:
# numpy.float64
